# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Convolution2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Flatten

# %%
from keras.preprocessing.image import ImageDataGenerator
td = ImageDataGenerator(rescale = 1./255,shear_range = 0.2,zoom_range = 0.2,horizontal_flip = True)
td = ImageDataGenerator(rescale = 1./255)

# %%
xtrain = td.flow_from_directory(r"C:\Users\USER\Downloads\Dataset_Objects\train",target_size = (64,64),batch_size = 9,class_mode = "categorical")
xtest = td.flow_from_directory(r"C:\Users\USER\Downloads\Dataset_Objects\test",target_size = (64,64),batch_size = 9,class_mode = "categorical")
# Out:
# Found 15 images belonging to 3 classes.
# Found 21 images belonging to 3 classes.

# %%
m = Sequential()

# %%
m.add(Convolution2D(32,(3,3),input_shape = (64,64,3),activation = "relu"))

# %%
m.add(MaxPooling2D(2,2))

# %%
m.add(Flatten())

# %%
m.add(Dense(units = 28,activation = "relu",kernel_initializer = "random_uniform"))

# %%
m.add(Dense(units = 3,activation = "softmax",kernel_initializer = "random_uniform"))

# %%
m.compile("sgd",loss = "categorical_crossentropy",metrics = ["accuracy"])

# %%
m.fit_generator(xtrain,steps_per_epoch = 5,epochs = 13,validation_data = xtest,validation_steps = 2 )
# Out:
# Epoch 1/13
# 5/5 [==============================] - 2s 475ms/step - loss: 1.1040 - acc: 0.3077 - val_loss: 1.0963 - val_acc: 0.3889
# Epoch 2/13
# 5/5 [==============================] - 1s 277ms/step - loss: 1.1007 - acc: 0.3056 - val_loss: 1.0849 - val_acc: 0.4444
# Epoch 3/13
# 5/5 [==============================] - 1s 267ms/step - loss: 1.0737 - acc: 0.3611 - val_loss: 1.0762 - val_acc: 0.3333
# Epoch 4/13
# 5/5 [==============================] - 1s 293ms/step - loss: 1.0783 - acc: 0.3590 - val_loss: 1.0668 - val_acc: 0.4444
# Epoch 5/13
# 5/5 [==============================] - 1s 275ms/step - loss: 1.0553 - acc: 0.4444 - val_loss: 1.0601 - val_acc: 0.3333
# Epoch 6/13
# 5/5 [==============================] - 1s 298ms/step - loss: 1.0413 - acc: 0.4103 - val_loss: 1.0487 - val_acc: 0.5556
# Epoch 7/13
# 5/5 [==============================] - 1s 293ms/step - loss: 1.0409 - acc: 0.5385 - val_loss: 1.0338 - val_acc: 0.6111
# Epoch 8/13
# 5/5 [==============================] - 2s 302ms/step - loss: 1.0067 - acc: 0.5278 - val_loss: 1.0180 - val_acc: 0.6111
# Epoch 9/13
# 5/5 [==============================] - 1s 293ms/step - loss: 0.9605 - acc: 0.6410 - val_loss: 1.0002 - val_acc: 0.5556
# Epoch 10/13
# 5/5 [==============================] - 1s 286ms/step - loss: 0.9621 - acc: 0.6389 - val_loss: 0.9735 - val_acc: 0.6667
# Epoch 11/13
# 5/5 [==============================] - 1s 299ms/step - loss: 0.8926 - acc: 0.7436 - val_loss: 0.9476 - val_acc: 0.6667
# Epoch 12/13
# 5/5 [==============================] - 1s 282ms/step - loss: 0.8933 - acc: 0.6667 - val_loss: 0.8997 - val_acc: 0.8333
# Epoch 13/13
# 5/5 [==============================] - 1s 274ms/step - loss: 0.8529 - acc: 0.8056 - val_loss: 0.8649 - val_acc: 0.8333

# %%
m.save("object.h5")

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
import cv2
import numpy as np

# %%
index = ["keyboard","monitor","mouse"]

# %%
model = load_model("object.h5")

# %%
img = image.load_img("mouse.jpg",target_size = (64,64))

# %%
x = image.img_to_array(img)

# %%
x = np.expand_dims(x,axis = 0)

# %%
pred = model.predict_classes(x)

# %%
pred[0]
# Out:
# 2

# %%
print(index[pred[0]])
# Out:
# mouse
